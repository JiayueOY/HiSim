# %%
# !git clone https://github.com/desenk/HiSim.git
# %cd ./HiSim
# !pip install -r requirements.txt
# Out:
# c:\Workspace\HiSim\examples\HiSim
# Cloning into 'HiSim'...
# Checking out files:  41% (119/287)
# Checking out files:  42% (121/287)
# Checking out files:  43% (124/287)
# Checking out files:  44% (127/287)
# Checking out files:  45% (130/287)
# Checking out files:  46% (133/287)
# Checking out files:  47% (135/287)
# Checking out files:  48% (138/287)
# Checking out files:  49% (141/287)
# Checking out files:  50% (144/287)
# Checking out files:  51% (147/287)
# Checking out files:  52% (150/287)
# Checking out files:  53% (153/287)
# Checking out files:  54% (155/287)
# Checking out files:  55% (158/287)
# Checking out files:  56% (161/287)
# Checking out files:  57% (164/287)
# Checking out files:  58% (167/287)
# Checking out files:  59% (170/287)
# Checking out files:  60% (173/287)
# Checking out files:  61% (176/287)
# Checking out files:  62% (178/287)
# Checking out files:  63% (181/287)
# Checking out files:  64% (184/287)
# Checking out files:  65% (187/287)
# ...

# %%
# %run ../hisim/hisim_main.py basic_household.py basic_household_explicit
# Out:
# LogPrio.Information:calling basic_household_explicit from basic_household.py
# LogPrio.Information:#################################
# LogPrio.Information:starting simulation of basic_household.py basic_household_explicit
# LogPrio.Information:Start @ 20-Apr-2022 15:28:43
# LogPrio.Profile:basic_household.py basic_household_explicitStart @ 20-Apr-2022 15:28:43
# LogPrio.Information:#################################
# LogPrio.Profile:Executing hisim.simulator.__init__ took 0.10 seconds
# LogPrio.Debug:adding output: NumberByResidents to component Occupancy
# LogPrio.Debug:adding output: HeatingByResidents to component Occupancy
# LogPrio.Debug:adding output: ElectricityOutput to component Occupancy
# LogPrio.Debug:adding output: WaterConsumption to component Occupancy
# LogPrio.Profile:Executing hisim.components.occupancy.__init__ took 3.84 seconds
# LogPrio.Information:Registering component outputs on Occupancy
# LogPrio.Information:Registered output Occupancy # NumberByResidents
# ...
